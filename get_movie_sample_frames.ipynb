# %% [markdown]
# <a href="https://colab.research.google.com/github/faezesarlakifar/face-emotion-recognition/blob/main/get_movie_sample_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import time

cam = cv2.VideoCapture("D:\\The100.mp4")

try:

	# creating a folder named data
	if not os.path.exists('data-04'):
		os.makedirs('data-04')

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

currentframe = 0

frame_rate = 1
prev = 0

while(True):

    time_elapsed = time.time() - prev
    res, image = cam.read()

    if time_elapsed > 1./frame_rate:
        prev = time.time()
        if res:
		# if video is still left continue creating images
        #  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
          name = './data-04/frame' + str(currentframe) + '.jpg'
          print ('Creating...' + name)
          cv2.imwrite(name, image)
          currentframe += 1
        else:
            break

cam.release()
cv2.destroyAllWindows()
# Out:
# Creating..../data-04/frame0.jpg
# Creating..../data-04/frame1.jpg
# Creating..../data-04/frame2.jpg
# Creating..../data-04/frame3.jpg
# Creating..../data-04/frame4.jpg
# Creating..../data-04/frame5.jpg
# Creating..../data-04/frame6.jpg
# Creating..../data-04/frame7.jpg
# Creating..../data-04/frame8.jpg
# Creating..../data-04/frame9.jpg
# Creating..../data-04/frame10.jpg
# Creating..../data-04/frame11.jpg
# Creating..../data-04/frame12.jpg
# Creating..../data-04/frame13.jpg
# Creating..../data-04/frame14.jpg
# Creating..../data-04/frame15.jpg
# Creating..../data-04/frame16.jpg
# Creating..../data-04/frame17.jpg
# Creating..../data-04/frame18.jpg
# Creating..../data-04/frame19.jpg
# Creating..../data-04/frame20.jpg
# Creating..../data-04/frame21.jpg
# Creating..../data-04/frame22.jpg
# Creating..../data-04/frame23.jpg
# Creating..../data-04/frame24.jpg
# Creating..../data-04/frame25.jpg
# Creating..../data-04/frame26.jpg
# Creating..../data-04/frame27.jpg
# ...
